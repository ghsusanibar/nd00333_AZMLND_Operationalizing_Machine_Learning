# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.17.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-124798
# aml-quickstarts-124798
# southcentralus
# 5e9e5b82-0802-460e-849e-48901a64399b

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'exp-automl-bankmkt'
project_folder = './pipeline-bike-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: exp-automl-bankmkt,
# Workspace: quick-starts-ws-124798)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "comp-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank-marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://udacitystorage.blob.core.windows.net/udacity/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `time_column_name` has to be `cnt` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted',
    "n_cross_validations": 5
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             #time_column_name="date", 
                             label_column_name="y",  
                             path = project_folder,
                             enable_early_stopping= True,
                             #featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [e0ee26bd][f479f75c-3dc1-4e84-a9cb-8f8bbddfcc66], (This step will run and generate new outputs)
# Submitted PipelineRun 81d68f0d-5e6b-4817-809f-c4b4ab01406b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/exp-automl-bankmkt/runs/81d68f0d-5e6b-4817-809f-c4b4ab01406b?wsid=/subscriptions/5e9e5b82-0802-460e-849e-48901a64399b/resourcegroups/aml-quickstarts-124798/workspaces/quick-starts-ws-124798

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 81d68f0d-5e6b-4817-809f-c4b4ab01406b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/exp-automl-bankmkt/runs/81d68f0d-5e6b-4817-809f-c4b4ab01406b?wsid=/subscriptions/5e9e5b82-0802-460e-849e-48901a64399b/resourcegroups/aml-quickstarts-124798/workspaces/quick-starts-ws-124798
# PipelineRun Status: Running
#
#
# StepRunId: 938cae6d-b032-4521-9877-44f9bc33be13
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/exp-automl-bankmkt/runs/938cae6d-b032-4521-9877-44f9bc33be13?wsid=/subscriptions/5e9e5b82-0802-460e-849e-48901a64399b/resourcegroups/aml-quickstarts-124798/workspaces/quick-starts-ws-124798
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '938cae6d-b032-4521-9877-44f9bc33be13', 'target': 'comp-cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-05T23:30:57.900658Z', 'endTimeUtc': '2020-11-06T00:00:48.452638Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '1511bd8e-05fe-4428-8f62-e9d8eb655ef1', 'StepType': 'AutoMLStep', 'azureml.moduleid': 'f479f75c-3dc1-4e84-a9cb-8f8bbddfcc66', 'azureml.nodeid': 'e0ee26bd', 'azureml.pipelinerunid': '81d68f0d-5e6b-4817-809f-c4b4ab01406b', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': '5', 'target': 'comp-cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "5e9e5b82-0802-460e-849e-48901a64399b", "resource_group": "aml-quickstarts-124798", "workspace_name": "quick-starts-ws-124798", "region": "southcentralus", "compute_target": "comp-cluster", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": 5, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LightGBM", "BernoulliNaiveBayes", "RandomForest", "DecisionTree", "XGBoostClassifier", "ExtremeRandomTrees", "LogisticRegression", "MultinomialNaiveBayes", "SGD", "LinearSVM", "AveragedPerceptronClassifier", "TensorFlowLinearClassifier", "TensorFlowDNN", "GradientBoosting", "SVM", "KNN"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"398c8637-93f4-4919-bcaa-689c5dd97546\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '1511bd8e-05fe-4428-8f62-e9d8eb655ef1', 'SetupRunId': '938cae6d-b032-4521-9877-44f9bc33be13_setup', 'SetupRunContainerId': 'dcid.938cae6d-b032-4521-9877-44f9bc33be13_setup', 'ClientSdkVersion': '1.17.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '938cae6d-b032-4521-9877-44f9bc33be13_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '81d68f0d-5e6b-4817-809f-c4b4ab01406b', 'status': 'Completed', 'startTimeUtc': '2020-11-05T23:30:23.923309Z', 'endTimeUtc': '2020-11-06T00:03:15.337198Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg124798.blob.core.windows.net/azureml/ExperimentRun/dcid.81d68f0d-5e6b-4817-809f-c4b4ab01406b/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=so5XfW2DD6Gkm%2B%2BTu%2FtDQQsCo5hwLRkvKLCaFCd%2FJAw%3D&st=2020-11-05T23%3A20%3A46Z&se=2020-11-06T07%3A30%3A46Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg124798.blob.core.windows.net/azureml/ExperimentRun/dcid.81d68f0d-5e6b-4817-809f-c4b4ab01406b/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=NjW8gegghdPQ7t2o6yi7BuWjEAMQ2zfGXpJyGuddv7E%3D&st=2020-11-05T23%3A20%3A47Z&se=2020-11-06T07%3A30%3A47Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg124798.blob.core.windows.net/azureml/ExperimentRun/dcid.81d68f0d-5e6b-4817-809f-c4b4ab01406b/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=7%2BL20H5vhjwXhUZUCK3avlP%2F6mq4BvXZ3zK5moH2FYk%3D&st=2020-11-05T23%3A20%3A47Z&se=2020-11-06T07%3A30%3A47Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/938cae6d-b032-4521-9877-44f9bc33be13/metrics_data
# Downloaded azureml/938cae6d-b032-4521-9877-44f9bc33be13/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  938cae6d-b032-4521-9877-44f9bc33be13_20  \
# recall_score_macro                                  [0.7153237481965193]
# recall_score_micro                                  [0.7182701062215479]
# weighted_accuracy                                   [0.7190047708768643]
# balanced_accuracy                                   [0.7153237481965193]
# norm_macro_recall                                   [0.4306474963930385]
# precision_score_micro                               [0.7182701062215479]
# precision_score_macro                               [0.5970463336649707]
# f1_score_micro                                      [0.7182701062215479]
# f1_score_weighted                                   [0.7679680142678835]
# accuracy                                            [0.7182701062215479]
# f1_score_macro                                      [0.5903378078122626]
# AUC_macro                                             [0.84470371212605]
# average_precision_score_weighted                    [0.9149207203029409]
# AUC_micro                                           [0.8284226986674528]
# precision_score_weighted                            [0.8723334009279096]
# average_precision_score_micro                       [0.8149918355048221]
# log_loss                                            [0.5258421455647296]
# AUC_weighted                                        [0.8447037121260502]
# matthews_correlation                               [0.28910004449176063]
# recall_score_weighted                               [0.7182701062215479]
# average_precision_score_macro                       [0.7042728149902834]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_27  \
# recall_score_macro                                   [0.667921079895774]
# recall_score_micro                                  [0.9057663125948408]
# weighted_accuracy                                   [0.9648543080315168]
# balanced_accuracy                                    [0.667921079895774]
# norm_macro_recall                                   [0.3358421597915481]
# precision_score_micro                               [0.9057663125948408]
# precision_score_macro                               [0.7843948505387486]
# f1_score_micro                                      [0.9057663125948408]
# f1_score_weighted                                   [0.8934250810839742]
# accuracy                                            [0.9057663125948408]
# f1_score_macro                                      [0.7032358116253514]
# AUC_macro                                           [0.9327937045742821]
# average_precision_score_weighted                    [0.9465036474906638]
# AUC_micro                                           [0.9733596404171493]
# precision_score_weighted                             [0.892517403067008]
# average_precision_score_micro                       [0.9697287502117146]
# log_loss                                           [0.22614994039872477]
# AUC_weighted                                        [0.9327937045742821]
# matthews_correlation                                [0.4347469025462655]
# recall_score_weighted                               [0.9057663125948408]
# average_precision_score_macro                       [0.7937588708033678]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_26  \
# recall_score_macro                                   [0.585034680852518]
# recall_score_micro                                  [0.8982094081942338]
# weighted_accuracy                                   [0.9759473746595511]
# balanced_accuracy                                    [0.585034680852518]
# norm_macro_recall                                  [0.17006936170503612]
# precision_score_micro                               [0.8982094081942338]
# precision_score_macro                               [0.7941120310977932]
# f1_score_micro                                      [0.8982094081942338]
# f1_score_weighted                                   [0.8675785643802316]
# accuracy                                            [0.8982094081942338]
# f1_score_macro                                      [0.5981569038533023]
# AUC_macro                                            [0.602815569713488]
# average_precision_score_weighted                    [0.8339909893676133]
# AUC_micro                                           [0.9031198141295611]
# precision_score_weighted                            [0.8809067138393806]
# average_precision_score_micro                       [0.8646351735542531]
# log_loss                                            [3.3194952481245616]
# AUC_weighted                                         [0.602815569713488]
# matthews_correlation                                [0.2753459034085847]
# recall_score_weighted                               [0.8982094081942338]
# average_precision_score_macro                       [0.5725587643233135]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_0  \
# recall_score_macro                                 [0.7536446104870343]
# recall_score_micro                                 [0.9153262518968133]
# weighted_accuracy                                   [0.955492910025417]
# balanced_accuracy                                  [0.7536446104870343]
# norm_macro_recall                                  [0.5072892209740687]
# precision_score_micro                              [0.9153262518968133]
# precision_score_macro                               [0.794327695398049]
# f1_score_micro                                     [0.9153262518968133]
# f1_score_weighted                                  [0.9122150096787482]
# accuracy                                           [0.9153262518968133]
# f1_score_macro                                     [0.7717552287143188]
# AUC_macro                                          [0.9491585177037773]
# average_precision_score_weighted                     [0.95612678389923]
# AUC_micro                                          [0.9811398610577022]
# precision_score_weighted                           [0.9102492525011827]
# average_precision_score_micro                      [0.9819407711877979]
# log_loss                                          [0.17223933574396963]
# AUC_weighted                                       [0.9491585177037773]
# matthews_correlation                               [0.5463876676498807]
# recall_score_weighted                              [0.9153262518968133]
# average_precision_score_macro                      [0.8268817690624332]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_7  \
# recall_score_macro                                 [0.6742674771954659]
# recall_score_micro                                 [0.9068285280728376]
# weighted_accuracy                                  [0.9646465098822778]
# balanced_accuracy                                  [0.6742674771954659]
# norm_macro_recall                                  [0.3485349543909317]
# precision_score_micro                              [0.9068285280728376]
# precision_score_macro                              [0.7856638707017923]
# f1_score_micro                                     [0.9068285280728375]
# f1_score_weighted                                  [0.8952085205405365]
# accuracy                                           [0.9068285280728376]
# f1_score_macro                                     [0.7094629860531949]
# AUC_macro                                          [0.9327857648671392]
# average_precision_score_weighted                   [0.9447502783076176]
# AUC_micro                                          [0.9740096757629277]
# precision_score_weighted                           [0.8938721650531309]
# average_precision_score_micro                      [0.9709044551856494]
# log_loss                                           [0.2160787187433178]
# AUC_weighted                                       [0.9327857648671392]
# matthews_correlation                              [0.44433351624638623]
# recall_score_weighted                              [0.9068285280728376]
# average_precision_score_macro                      [0.7842931673299736]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_12  \
# recall_score_macro                                  [0.6260612455527882]
# recall_score_micro                                  [0.9035204855842185]
# weighted_accuracy                                   [0.9724746232815414]
# balanced_accuracy                                   [0.6260612455527882]
# norm_macro_recall                                  [0.25212249110557633]
# precision_score_micro                               [0.9035204855842185]
# precision_score_macro                               [0.7955517732443015]
# f1_score_micro                                      [0.9035204855842185]
# f1_score_weighted                                   [0.8842821805327041]
# accuracy                                            [0.9035204855842185]
# f1_score_macro                                      [0.6649439599681931]
# AUC_macro                                           [0.9235014241817925]
# average_precision_score_weighted                    [0.9422776055008418]
# AUC_micro                                           [0.9732168849201324]
# precision_score_weighted                            [0.8876507503331329]
# average_precision_score_micro                       [0.9733132618366991]
# log_loss                                           [0.25154986037157745]
# AUC_weighted                                        [0.9235014241817925]
# matthews_correlation                                [0.3848234429779563]
# recall_score_weighted                               [0.9035204855842185]
# average_precision_score_macro                       [0.7801076037902501]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_5  \
# recall_score_macro                                 [0.5897621875698299]
# recall_score_micro                                 [0.9001213960546283]
# weighted_accuracy                                  [0.9772055380176493]
# balanced_accuracy                                  [0.5897621875698299]
# norm_macro_recall                                 [0.17952437513965966]
# precision_score_micro                              [0.9001213960546283]
# precision_score_macro                              [0.8038813659369787]
# f1_score_micro                                     [0.9001213960546283]
# f1_score_weighted                                  [0.8736639747432161]
# accuracy                                           [0.9001213960546283]
# f1_score_macro                                     [0.6223512491050333]
# AUC_macro                                          [0.8932488320582117]
# average_precision_score_weighted                    [0.930539022813566]
# AUC_micro                                          [0.9667176689746961]
# precision_score_weighted                            [0.883413963726466]
# average_precision_score_micro                      [0.9676017433445481]
# log_loss                                          [0.24498302673199196]
# AUC_weighted                                       [0.8932488320582117]
# matthews_correlation                               [0.3301121618244641]
# recall_score_weighted                              [0.9001213960546283]
# average_precision_score_macro                      [0.7424924699382645]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_28  \
# recall_score_macro                                  [0.6066787020363605]
# recall_score_micro                                  [0.9025493171471928]
# weighted_accuracy                                   [0.9760726966851513]
# balanced_accuracy                                   [0.6066787020363605]
# norm_macro_recall                                  [0.21335740407272125]
# precision_score_micro                               [0.9025493171471928]
# precision_score_macro                               [0.8131503730887351]
# f1_score_micro                                      [0.9025493171471928]
# f1_score_weighted                                   [0.8791065149825489]
# accuracy                                            [0.9025493171471928]
# f1_score_macro                                      [0.6427973745245721]
# AUC_macro                                           [0.9294833388226657]
# average_precision_score_weighted                    [0.9447396852529797]
# AUC_micro                                           [0.9740998109518951]
# precision_score_weighted                            [0.8883209586531982]
# average_precision_score_micro                       [0.9739778589041087]
# log_loss                                           [0.26967017914234837]
# AUC_weighted                                        [0.9294833388226657]
# matthews_correlation                               [0.36239163464604385]
# recall_score_weighted                               [0.9025493171471928]
# average_precision_score_macro                       [0.7887511668726881]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_32  \
# recall_score_macro                                  [0.7436047669184538]
# recall_score_micro                                  [0.7861608497723823]
# weighted_accuracy                                   [0.7967332592198432]
# balanced_accuracy                                   [0.7436047669184538]
# norm_macro_recall                                  [0.48720953383690757]
# precision_score_micro                               [0.7861608497723823]
# precision_score_macro                                [0.627263421105788]
# f1_score_micro                                      [0.7861608497723823]
# f1_score_weighted                                   [0.8185668172190013]
# accuracy                                            [0.7861608497723823]
# f1_score_macro                                      [0.6440848818010956]
# AUC_macro                                           [0.8105115015218219]
# average_precision_score_weighted                    [0.9054528095646495]
# AUC_micro                                           [0.8369255205730852]
# precision_score_weighted                            [0.8801178968154355]
# average_precision_score_micro                       [0.8086819950137171]
# log_loss                                             [0.529378013825744]
# AUC_weighted                                        [0.8105115015218219]
# matthews_correlation                                [0.3521245959278126]
# recall_score_weighted                               [0.7861608497723823]
# average_precision_score_macro                       [0.7029228687594917]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_4  ...  \
# recall_score_macro                                 [0.6892458385547566]  ...
# recall_score_micro                                 [0.9081335356600911]  ...
# weighted_accuracy                                  [0.9625398425345644]  ...
# balanced_accuracy                                  [0.6892458385547566]  ...
# norm_macro_recall                                  [0.3784916771095133]  ...
# precision_score_micro                              [0.9081335356600911]  ...
# precision_score_macro                              [0.7861113436069119]  ...
# f1_score_micro                                     [0.9081335356600911]  ...
# f1_score_weighted                                   [0.898729904205207]  ...
# accuracy                                           [0.9081335356600911]  ...
# f1_score_macro                                     [0.7231960719275049]  ...
# AUC_macro                                          [0.9255564934837706]  ...
# average_precision_score_weighted                   [0.9434669830012131]  ...
# AUC_micro                                          [0.9728303471715318]  ...
# precision_score_weighted                           [0.8966377081044895]  ...
# average_precision_score_micro                      [0.9715841318233827]  ...
# log_loss                                           [0.3062028984071402]  ...
# AUC_weighted                                       [0.9255564934837706]  ...
# matthews_correlation                               [0.4646313579899334]  ...
# recall_score_weighted                              [0.9081335356600911]  ...
# average_precision_score_macro                      [0.7869085749046627]  ...
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_18  \
# recall_score_macro                                  [0.8327125947343326]
# recall_score_micro                                   [0.845402124430956]
# weighted_accuracy                                   [0.8486224137009349]
# balanced_accuracy                                   [0.8327125947343326]
# norm_macro_recall                                   [0.6654251894686651]
# precision_score_micro                                [0.845402124430956]
# precision_score_macro                               [0.6905018768630525]
# f1_score_micro                                       [0.845402124430956]
# f1_score_weighted                                   [0.8661118662800169]
# accuracy                                             [0.845402124430956]
# f1_score_macro                                      [0.7248006954915347]
# AUC_macro                                           [0.9091550820101254]
# average_precision_score_weighted                     [0.937122492785741]
# AUC_micro                                           [0.8920688125890839]
# precision_score_weighted                             [0.910066933300358]
# average_precision_score_micro                       [0.8615646753153058]
# log_loss                                           [0.43267933809679693]
# AUC_weighted                                        [0.9091550820101254]
# matthews_correlation                                  [0.50324326740305]
# recall_score_weighted                                [0.845402124430956]
# average_precision_score_macro                        [0.764408059983999]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_21  \
# recall_score_macro                                  [0.7158697301108685]
# recall_score_micro                                  [0.7192412746585737]
# weighted_accuracy                                    [0.720080098570239]
# balanced_accuracy                                   [0.7158697301108685]
# norm_macro_recall                                   [0.4317394602217367]
# precision_score_micro                               [0.7192412746585737]
# precision_score_macro                               [0.5974343544538847]
# f1_score_micro                                      [0.7192412746585737]
# f1_score_weighted                                   [0.7687101521254199]
# accuracy                                            [0.7192412746585737]
# f1_score_macro                                      [0.5911034292507844]
# AUC_macro                                           [0.8397438767701118]
# average_precision_score_weighted                    [0.9133610964314606]
# AUC_micro                                           [0.8341900382471257]
# precision_score_weighted                            [0.8724714577827257]
# average_precision_score_micro                         [0.82057856106141]
# log_loss                                            [0.5311891618376323]
# AUC_weighted                                        [0.8397438767701118]
# matthews_correlation                                  [0.29004598572365]
# recall_score_weighted                               [0.7192412746585737]
# average_precision_score_macro                       [0.7031776225856994]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_10  \
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8879514415781488]
# weighted_accuracy                                   [0.9843203159290127]
# balanced_accuracy                                                  [0.5]
# norm_macro_recall                                                  [0.0]
# precision_score_micro                               [0.8879514415781488]
# precision_score_macro                               [0.4439757207890744]
# f1_score_micro                                      [0.8879514415781488]
# f1_score_weighted                                     [0.83525313620102]
# accuracy                                            [0.8879514415781488]
# f1_score_macro                                     [0.47032487347763857]
# AUC_macro                                           [0.8959496193369711]
# average_precision_score_weighted                    [0.9283806470335285]
# AUC_micro                                           [0.9667587713945579]
# precision_score_weighted                            [0.7884610378994246]
# average_precision_score_micro                       [0.9679272412939003]
# log_loss                                             [0.264368099940083]
# AUC_weighted                                        [0.8959496193369711]
# matthews_correlation                                               [0.0]
# recall_score_weighted                               [0.8879514415781488]
# average_precision_score_macro                       [0.7303961337027861]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_13  \
# recall_score_macro                                  [0.7477497734155781]
# recall_score_micro                                  [0.7606980273141123]
# weighted_accuracy                                   [0.7639372105525495]
# balanced_accuracy                                   [0.7477497734155781]
# norm_macro_recall                                  [0.49549954683115593]
# precision_score_micro                               [0.7606980273141123]
# precision_score_macro                               [0.6203878949247477]
# f1_score_micro                                      [0.7606980273141123]
# f1_score_weighted                                   [0.8003534545416826]
# accuracy                                            [0.7606980273141123]
# f1_score_macro                                      [0.6289024823849403]
# AUC_macro                                           [0.8498870125129789]
# average_precision_score_weighted                    [0.9143905631990975]
# AUC_micro                                           [0.8449156928348236]
# precision_score_weighted                            [0.8818459447875311]
# average_precision_score_micro                       [0.8303772748919191]
# log_loss                                            [0.5953666614541879]
# AUC_weighted                                        [0.8498870125129789]
# matthews_correlation                               [0.34530252221134783]
# recall_score_weighted                               [0.7606980273141123]
# average_precision_score_macro                       [0.6979023555290174]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_38  \
# recall_score_macro                                  [0.7398185467524867]
# recall_score_micro                                  [0.9158421851289832]
# weighted_accuracy                                   [0.9595654212351864]
# balanced_accuracy                                   [0.7398185467524867]
# norm_macro_recall                                  [0.47963709350497313]
# precision_score_micro                               [0.9158421851289832]
# precision_score_macro                               [0.8007103242023549]
# f1_score_micro                                      [0.9158421851289832]
# f1_score_weighted                                   [0.9111569751517207]
# accuracy                                            [0.9158421851289832]
# f1_score_macro                                      [0.7653010897267291]
# AUC_macro                                           [0.9496640788619782]
# average_precision_score_weighted                    [0.9564911129104134]
# AUC_micro                                            [0.981285163292891]
# precision_score_weighted                            [0.9089970057637304]
# average_precision_score_micro                       [0.9820681568065917]
# log_loss                                           [0.17333855179947413]
# AUC_weighted                                        [0.9496640788619783]
# matthews_correlation                                [0.5369403547182726]
# recall_score_weighted                               [0.9158421851289832]
# average_precision_score_macro                       [0.8283391986613247]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_6  \
# recall_score_macro                                 [0.5935645694046674]
# recall_score_micro                                 [0.8990591805766313]
# weighted_accuracy                                  [0.9749400667575655]
# balanced_accuracy                                  [0.5935645694046674]
# norm_macro_recall                                 [0.18712913880933485]
# precision_score_micro                              [0.8990591805766313]
# precision_score_macro                              [0.7873609647508857]
# f1_score_micro                                     [0.8990591805766313]
# f1_score_weighted                                  [0.8740264179154191]
# accuracy                                           [0.8990591805766313]
# f1_score_macro                                     [0.6263127447427445]
# AUC_macro                                          [0.9053767912531188]
# average_precision_score_weighted                   [0.9323554467720093]
# AUC_micro                                          [0.9691186489853344]
# precision_score_weighted                           [0.8803744381130176]
# average_precision_score_micro                       [0.968889053146223]
# log_loss                                          [0.23160888543447297]
# AUC_weighted                                       [0.9053767912531185]
# matthews_correlation                               [0.3275677901179798]
# recall_score_weighted                              [0.8990591805766313]
# average_precision_score_macro                      [0.7471027061570623]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_19  \
# recall_score_macro                                                 [0.5]
# recall_score_micro                                  [0.8879514415781488]
# weighted_accuracy                                   [0.9843203159290127]
# balanced_accuracy                                                  [0.5]
# norm_macro_recall                                                  [0.0]
# precision_score_micro                               [0.8879514415781488]
# precision_score_macro                               [0.4439757207890744]
# f1_score_micro                                      [0.8879514415781488]
# f1_score_weighted                                     [0.83525313620102]
# accuracy                                            [0.8879514415781488]
# f1_score_macro                                     [0.47032487347763857]
# AUC_macro                                           [0.8762023579085438]
# average_precision_score_weighted                    [0.9202038897455914]
# AUC_micro                                           [0.9628294721620334]
# precision_score_weighted                            [0.7884610378994246]
# average_precision_score_micro                       [0.9635737947791536]
# log_loss                                            [0.2787924808426455]
# AUC_weighted                                        [0.8762023579085438]
# matthews_correlation                                               [0.0]
# recall_score_weighted                               [0.8879514415781488]
# average_precision_score_macro                       [0.7060937445485838]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_39  \
# recall_score_macro                                  [0.7322557558792012]
# recall_score_micro                                  [0.9157814871016692]
# weighted_accuracy                                   [0.9613775388480045]
# balanced_accuracy                                   [0.7322557558792012]
# norm_macro_recall                                  [0.46451151175840266]
# precision_score_micro                               [0.9157814871016692]
# precision_score_macro                               [0.8033103844383678]
# f1_score_micro                                      [0.9157814871016692]
# f1_score_weighted                                     [0.91024232263453]
# accuracy                                            [0.9157814871016692]
# f1_score_macro                                      [0.7610288494049499]
# AUC_macro                                           [0.9490737037924257]
# average_precision_score_weighted                    [0.9563147492152447]
# AUC_micro                                           [0.9810548792141492]
# precision_score_weighted                            [0.9081270047845262]
# average_precision_score_micro                       [0.9818688405570611]
# log_loss                                           [0.19397673728008924]
# AUC_weighted                                        [0.9490737037924257]
# matthews_correlation                                [0.5306477231223743]
# recall_score_weighted                               [0.9157814871016692]
# average_precision_score_macro                       [0.8277754365074476]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_17  \
# recall_score_macro                                  [0.6292118472120333]
# recall_score_micro                                  [0.9004552352048558]
# weighted_accuracy                                   [0.9678448053723443]
# balanced_accuracy                                   [0.6292118472120333]
# norm_macro_recall                                   [0.2584236944240665]
# precision_score_micro                               [0.9004552352048558]
# precision_score_macro                               [0.7743021212910186]
# f1_score_micro                                      [0.9004552352048559]
# f1_score_weighted                                   [0.8823023933706751]
# accuracy                                            [0.9004552352048558]
# f1_score_macro                                      [0.6623552630602305]
# AUC_macro                                           [0.9009209285967767]
# average_precision_score_weighted                     [0.933477142119615]
# AUC_micro                                           [0.9683756553936277]
# precision_score_weighted                            [0.8836335006736455]
# average_precision_score_micro                       [0.9686230844046431]
# log_loss                                           [0.23738346038259522]
# AUC_weighted                                        [0.9009209285967767]
# matthews_correlation                                [0.3715071516924347]
# recall_score_weighted                               [0.9004552352048558]
# average_precision_score_macro                       [0.7511201175589102]
#
#                                  938cae6d-b032-4521-9877-44f9bc33be13_30
# recall_score_macro                                  [0.8329913383539271]
# recall_score_micro                                  [0.8339908952959029]
# weighted_accuracy                                   [0.8341028820312897]
# balanced_accuracy                                   [0.8329913383539271]
# norm_macro_recall                                   [0.6659826767078544]
# precision_score_micro                               [0.8339908952959029]
# precision_score_macro                               [0.6849106726536379]
# f1_score_micro                                      [0.8339908952959029]
# f1_score_weighted                                   [0.8576513841617546]
# accuracy                                            [0.8339908952959029]
# f1_score_macro                                      [0.7153927189877869]
# AUC_macro                                           [0.9121080148852603]
# average_precision_score_weighted                    [0.9376499251824013]
# AUC_micro                                             [0.89468328570672]
# precision_score_weighted                             [0.910367279053123]
# average_precision_score_micro                       [0.8709157597518125]
# log_loss                                            [0.5272221587897148]
# AUC_weighted                                        [0.9121080148852603]
# matthews_correlation                               [0.49555094225349416]
# recall_score_weighted                               [0.8339908952959029]
# average_precision_score_macro                       [0.7651279525899619]
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/938cae6d-b032-4521-9877-44f9bc33be13/model_data
# Downloaded azureml/938cae6d-b032-4521-9877-44f9bc33be13/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(allow_chargram=None,
#                                                                   enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=Non...
#                                                                                                                                    learning_rate='constant',
#                                                                                                                                    loss='squared_hinge',
#                                                                                                                                    max_iter=1000,
#                                                                                                                                    n_jobs=1,
#                                                                                                                                    penalty='none',
#                                                                                                                                    power_t=0.3333333333333333,
#                                                                                                                                    random_state=None,
#                                                                                                                                    tol=0.001))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.6666666666666666,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(allow_chargram=None, enable_dnn=None,
#                   enable_feature_sweeping=None, feature_sweeping_config=None,
#                   feature_sweeping_timeout=None, featurization_config=None,
#                   force_text_dnn=None, is_cross_validation=None,
#                   is_onnx_compatible=None, logger=None, observer=None, task=None,
#                   working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                    eta0=0.001,
#                                                                                    fit_intercept=False,
#                                                                                    l1_ratio=0.3877551020408163,
#                                                                                    learning_rate='constant',
#                                                                                    loss='squared_hinge',
#                                                                                    max_iter=1000,
#                                                                                    n_jobs=1,
#                                                                                    penalty='none',
#                                                                                    power_t=0.3333333333333333,
#                                                                                    random_state=None,
#                                                                                    tol=0.001))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.6666666666666666, 0.13333333333333333,
#                                          0.06666666666666667, 0.06666666666666667,
#                                          0.06666666666666667]))]

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bank Marketing  Train", description="Training bank marketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bank Marketing  Train,
# Id: a9544904-2852-4823-b19b-b2e06c920827,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/5e9e5b82-0802-460e-849e-48901a64399b/resourceGroups/aml-quickstarts-124798/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-124798/PipelineRuns/PipelineSubmit/a9544904-2852-4823-b19b-b2e06c920827)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %% [markdown]
# ## Schedule Pipeline

# %%
from azureml.pipeline.core import Pipeline, PublishedPipeline

published_pipelines = PublishedPipeline.list(ws)
for published_pipeline in  published_pipelines:
    print(f"{published_pipeline.name},'{published_pipeline.id}'")
# Out:
# Bank Marketing  Train,'a9544904-2852-4823-b19b-b2e06c920827'
# Bank Marketing  Train,'af6861f0-d02f-460d-8d4f-56dc9dd63aeb'

# %%
from azureml.pipeline.core.schedule import ScheduleRecurrence, Schedule

recurrence = ScheduleRecurrence(frequency="Hour", interval=24)
recurring_schedule = Schedule.create(ws, name="MyRecurringSchedule", 
                            description="Based on time",
                            pipeline_id="a9544904-2852-4823-b19b-b2e06c920827", 
                            experiment_name="exp-automl-bankmkt", 
                            recurrence=recurrence)

# %%
recurring_schedule
# Out:
# Pipeline(Name: MyRecurringSchedule,
# Id: 3e56cfe0-2416-4602-9d62-fac4b1f1a77c,
# Status: Active,
# Pipeline Id: a9544904-2852-4823-b19b-b2e06c920827,
# Pipeline Endpoint Id: None,
# Recurrence Details: Runs every 24 Hours)

# %% [markdown]
# ## Run Pipeline REST endpoint

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "exp-automl-bankmkt"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  17b7951c-21c7-4150-a0d3-48fb02b4a7c5

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["exp-automl-bankmkt"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
